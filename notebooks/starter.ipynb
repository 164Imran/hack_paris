# %% [markdown]
# # Challenge Starter Notebook

# %%
import torch
import torch.nn as nn
import numpy as np
import pandas as pd

print(f'PyTorch {torch.__version__}')
print(f'CUDA available: {torch.cuda.is_available()}')

# %%
# TODO: load data here

# %%
# TODO: define model here

# %%
# TODO: training loop
